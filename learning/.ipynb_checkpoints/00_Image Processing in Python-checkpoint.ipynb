# %%
# %matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt

import skimage
from skimage import data

# %%
camera = data.camera()

# %%
camera
# Out:
# array([[156, 157, 160, ..., 152, 152, 152],
#        [156, 157, 159, ..., 152, 152, 152],
#        [158, 157, 156, ..., 152, 152, 152],
#        ...,
#        [121, 123, 126, ..., 121, 113, 111],
#        [121, 123, 126, ..., 121, 113, 111],
#        [121, 123, 126, ..., 121, 113, 111]], dtype=uint8)

# %%
type(camera)
# Out:
# numpy.ndarray

# %%
camera.shape
# Out:
# (512, 512)

# %%
camera.size
# Out:
# 262144

# %%
plt.imshow(camera,'gray')
plt.axis('off')
plt.title('Camera')
# Out:
# Text(0.5,1,'Camera')

# %%
camera.min(),camera.max()
# Out:
# (0, 255)

# %%
camera.mean()
# Out:
# 118.31400299072266

# %%
from skimage import io

colony = io.imread('../images/yeast_colony_array.jpg')

plt.imshow(colony)

# %%
colony.shape
# Out:
# (1059, 1571, 3)

# %%
plt.imshow(colony[:,:,0])
plt.axis('off')
plt.title('Yeast Colony')
# Out:
# Text(0.5,1,'Yeast Colony')

# %%
camera = data.camera()
camera[10,20]
# Out:
# 153

# %%
camera[3,10] = 0
plt.imshow(camera,'gray')

# %%
camera[:,10] = 0
plt.imshow(camera,'gray')

# %%
camera[:100] = 0
plt.imshow(camera,'gray')

# %%
camera = data.camera()

mask = camera < 87

camera[mask] = 255

plt.imshow(camera,'gray')

# %%
cat = data.chelsea()
plt.imshow(cat)

# %%
cat.shape
# Out:
# (300, 451, 3)

# %%
cat[50,60,:]
# Out:
# array([160, 118,  78], dtype=uint8)

# %%
cat[50,60,:] = [0,255,0]
plt.imshow(cat)

# %%
cat = data.chelsea()

red_cat = cat.copy()
mask = cat[:,:,0] > 160
red_cat[mask] = [255,0,0]
plt.imshow(red_cat)

# %%
BGR_cat = cat[:,:,::-1]
plt.imshow(BGR_cat)

# %%
from skimage import util
inverted_cat = util.invert(cat)
plt.imshow(inverted_cat)

# %%
plt.imshow(cat)

# %%
inverted_cat[0,:10,0]
# Out:
# array([112, 112, 114, 114, 114, 114, 114, 112, 111, 110], dtype=uint8)

# %%
cat[0,:10,0]
# Out:
# array([143, 143, 141, 141, 141, 141, 141, 143, 144, 145], dtype=uint8)

# %%
f,ax = plt.subplots()

ax.plot(inverted_cat[0,:10,0])

ax.plot(cat[0,:10,0])

ax.legend()
# Out:
# No handles with labels found to put in legend.

# %%
img = data.camera()
img.shape,img.size
# Out:
# ((512, 512), 262144)

# %%
img.ravel(),len(img.ravel())
# Out:
# (array([156, 157, 160, ..., 121, 113, 111], dtype=uint8), 262144)

# %% [markdown]
# ## __分号的作用__

# %%
plt.hist(img.ravel(),bins=256,); # add ';' at the end of the command line

# %%
plt.hist(img.ravel(),bins=256,histtype='step');

# %%
plt.hist(img.ravel(),bins=256,histtype='step',color='black');

# %%
plt.imshow(img,'gray');

# %%
plt.imshow(colony);

# %% [markdown]
# ## __rgb2gray__

# %%
from skimage.color import rgb2gray

img = rgb2gray(colony)

# %%
img.shape
# Out:
# (1059, 1571)

# %%
plt.imshow(img);

# %%
plt.hist(img.ravel(),bins=256,histtype='step',color='black');

# %%
plt.imshow(img > 0.5);

# %%
from skimage.filters import sobel
from skimage.morphology import watershed

# %%
elevation = sobel(img)
plt.imshow(elevation,cmap='gray');

# %%
masks = np.zeros_like(img)

masks[img < 0.35] = 1

masks[img > 0.55] = 2

plt.imshow(masks);

# %%
segmentation = watershed(elevation,masks)
segmentation[segmentation == 1] = 0
plt.imshow(segmentation);
plt.axis('off');

# %%
from scipy import ndimage as ndi
labeled,number = ndi.label(segmentation)

# %%
plt.imshow(labeled)

# %%
number
# Out:
# 1481

# %%
36 * 48
# Out:
# 1728

# %%
import matplotlib.pyplot as plt
import numpy as np

# 绘制普通图像
x = np.linspace(-3, 3, 50)
y = 2 * x + 1

plt.figure()
plt.plot(x, y)

# 将上、右边框去掉
ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

# 设置x轴的位置及数据在坐标轴上的位置
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data', 0))
# 设置y轴的位置及数据在坐标轴上的位置
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data', 0))

# 设置坐标轴label的大小，背景色等信息
for label in ax.get_xticklabels() + ax.get_yticklabels():
    label.set_fontsize(12)
    label.set_bbox(dict(facecolor = 'green', edgecolor = 'None', alpha = 0.7))

plt.show()
